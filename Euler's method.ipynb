# %%
import matplotlib.pyplot as plt
g=9.8
c=12.5
m=68.1
x=[]
def euler(step):
    v=0
    k=0
    for a in range(15):
        t=v+(g-(c/m)*v)*step
        x.append(v)
        print(f't={k}s vel={v}m/s')
        k=k+step
        v=t
        
        
euler(2)
plt.plot(x)
plt.show()
# Out:
# t=0s vel=0m/s
# t=2s vel=19.6m/s
# t=4s vel=32.00469897209986m/s
# t=6s vel=39.85554369599859m/s
# t=8s vel=44.82428683256299m/s
# t=10s vel=47.968968612092m/s
# t=12s vel=49.959215083423864m/s
# t=14s vel=51.21882775470732m/s
# t=16s vel=52.01602755107027m/s
# t=18s vel=52.52056956609587m/s
# t=20s vel=52.83989057707389m/s
# t=22s vel=53.04198654731108m/s
# t=24s vel=53.169891632732856m/s
# t=26s vel=53.250841840980705m/s
# t=28s vel=53.30207464531965m/s
